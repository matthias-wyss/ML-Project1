# %%
from helpers import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from implementations import *
from utils import *
import utils
import preprocess
import importlib
importlib.reload(utils)
importlib.reload(preprocess)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x_train, x_test, y_train, train_ids, test_ids = load_csv_data("data/dataset")

# %%
avg_accuracy, avg_f1 = cross_validate(
    x_train,
    y_train,
    k=5,
    method='least_squares',
    replace_nan_by=-1,
    column_nan_threshold=0.01,
    row_nan_threshold=0.01,
    continuous_threshold=0,
    normalization_method='standardize',
    outliers='remove',
    z_score_threshold=3,
    max_false_percentage=0.3,
    balance_method=None,
    target_minority_ratio=0.6,
    add_bias=False,
    pca_components=50,
    lambda_=0.1,
    initial_w=None,
    max_iters=1000,
    gamma=0.01,
    preprocess_verbose=True,
    cross_validation_verbose=True
)
# Out:
# Preprocessing for fold 1:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Removed 0 outliers (z-score > 3).
# PCA performs to reach 50 components.
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6019
# F1 Score: 0.2877
#
# Preprocessing for fold 2:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Removed 0 outliers (z-score > 3).
# PCA performs to reach 50 components.
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6032
# F1 Score: 0.2884
#
# Preprocessing for fold 3:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Removed 0 outliers (z-score > 3).
# PCA performs to reach 50 components.
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6042
# F1 Score: 0.2862
#
# Preprocessing for fold 4:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Removed 0 outliers (z-score > 3).
# PCA performs to reach 50 components.
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6038
# F1 Score: 0.2877
#
# Preprocessing for fold 5:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Removed 0 outliers (z-score > 3).
# PCA performs to reach 50 components.
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6020
# F1 Score: 0.2810
#
# Method: least_squares
# Average accuracy: 0.6030, Average F1-Score: 0.2862

# %%
predict_with_method(
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    test_ids=test_ids,
    method='least_squares',
    lambda_=0.1,
    initial_w=None,
    max_iters=1000,
    gamma=0.01,
    replace_nan_by=-1,
    column_nan_threshold=0.01,
    row_nan_threshold=0.01,
    continuous_threshold=0,
    normalization_method='standardize',
    outliers='remove',
    z_score_threshold=3,
    max_false_percentage=0.3,
    balance_method=None,
    target_minority_ratio=0,
    add_bias=False,
    pca_components=50,
    preprocess_verbose=True
)
# Out:
# Preprocessing data...
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Removed 0 outliers (z-score > 3).
# PCA performs to reach 50 components.
# Number of predicted labels -1: 58343
# Number of predicted labels 1: 51036
# array([[328135,      1],
#        [328136,     -1],
#        [328137,      1],
#        ...,
#        [437511,      1],
#        [437512,      1],
#        [437513,      1]])

# %%
# Least squares hyperparameter tuning

best_avg_accuracy = 0
best_avg_f1 = 0

# Best parameters storage
best_params_accuracy = {
    'replace_nan_by': None,
    'column_nan_threshold': None,
    'row_nan_threshold': None,
    'continuous_threshold': None,
    'normalization_method': None,
    'outliers': None,
    'z_score_threshold': None,
    'max_false_percentage': None,
    'balance_method': None,
    'target_minority_ratio': None,
    'add_bias': None,
    'pca_components': None
}

best_params_f1 = {
    'replace_nan_by': None,
    'column_nan_threshold': None,
    'row_nan_threshold': None,
    'continuous_threshold': None,
    'normalization_method': None,
    'outliers': None,
    'z_score_threshold': None,
    'max_false_percentage': None,
    'balance_method': None,
    'target_minority_ratio': None,
    'add_bias': None,
    'pca_components': None
}

# Iterate through parameter combinations
for replace_nan_by in [None, -1]:
    for column_nan_threshold in [0.01, 0.05]:
        for row_nan_threshold in [0.01, 0.05]:
            for continuous_threshold in [0]:
                for normalization_method in ['standardize', 'normalize']:
                    for outliers in ['remove', 'clip']:
                        for z_score_threshold in [3]:
                            for max_false_percentage in [0.1, 0.3, 0.5]:
                                for balance_method in ['downsampling', 'upsampling']:
                                    for target_minority_ratio in [0.25, 0.5, 0.75, 1]:
                                        for add_bias in [False, True]:
                                            for pca_components in [10, 20, 30, 40, 50, 60, 70]:

                                                # Call cross-validation
                                                avg_accuracy, avg_f1 = cross_validate(
                                                    x_train,
                                                    y_train,
                                                    k=5,
                                                    method='least_squares',
                                                    replace_nan_by=replace_nan_by,
                                                    column_nan_threshold=column_nan_threshold,
                                                    row_nan_threshold=row_nan_threshold,
                                                    continuous_threshold=continuous_threshold,
                                                    normalization_method=normalization_method,
                                                    outliers=outliers,
                                                    z_score_threshold=z_score_threshold,
                                                    max_false_percentage=max_false_percentage,
                                                    balance_method=balance_method,
                                                    target_minority_ratio=target_minority_ratio,
                                                    add_bias=add_bias,
                                                    pca_components=pca_components,
                                                    preprocess_verbose=False,
                                                    cross_validation_verbose=True
                                                )

                                                # Update best average accuracy
                                                if avg_accuracy > best_avg_accuracy:
                                                    best_avg_accuracy = avg_accuracy
                                                    best_params_accuracy.update({
                                                        'replace_nan_by': replace_nan_by,
                                                        'column_nan_threshold': column_nan_threshold,
                                                        'row_nan_threshold': row_nan_threshold,
                                                        'continuous_threshold': continuous_threshold,
                                                        'normalization_method': normalization_method,
                                                        'outliers': outliers,
                                                        'z_score_threshold': z_score_threshold,
                                                        'max_false_percentage': max_false_percentage,
                                                        'balance_method': balance_method,
                                                        'target_minority_ratio': target_minority_ratio,
                                                        'add_bias': add_bias,
                                                        'pca_components': pca_components
                                                    })

                                                # Update best average F1 score
                                                if avg_f1 > best_avg_f1:
                                                    best_avg_f1 = avg_f1
                                                    best_params_f1.update({
                                                        'replace_nan_by': replace_nan_by,
                                                        'column_nan_threshold': column_nan_threshold,
                                                        'row_nan_threshold': row_nan_threshold,
                                                        'continuous_threshold': continuous_threshold,
                                                        'normalization_method': normalization_method,
                                                        'outliers': outliers,
                                                        'z_score_threshold': z_score_threshold,
                                                        'max_false_percentage': max_false_percentage,
                                                        'balance_method': balance_method,
                                                        'target_minority_ratio': target_minority_ratio,
                                                        'add_bias': add_bias,
                                                        'pca_components': pca_components
                                                    })

# Print results
print("Best Average Accuracy:", best_avg_accuracy)
print("Best Parameters for Accuracy:", best_params_accuracy)
print("Best Average F1 Score:", best_avg_f1)
print("Best Parameters for F1 Score:", best_params_f1)
# Out:
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6009
# F1 Score: 0.2823
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6017
# F1 Score: 0.2816
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.5988
# F1 Score: 0.2765
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6009
# F1 Score: 0.2788
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6029
# F1 Score: 0.2742
#
# Method: least_squares
# Average accuracy: 0.6011, Average F1-Score: 0.2787
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6155
# F1 Score: 0.2953
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6165
# F1 Score: 0.2954
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6155
# F1 Score: 0.2917
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6167
# F1 Score: 0.2934
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6173
# F1 Score: 0.2873
#
# Method: least_squares
# Average accuracy: 0.6163, Average F1-Score: 0.2926
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6297
# F1 Score: 0.2994
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6311
# F1 Score: 0.2999
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6321
# F1 Score: 0.2979
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6318
# F1 Score: 0.2982
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6312
# F1 Score: 0.2924
#
# Method: least_squares
# Average accuracy: 0.6312, Average F1-Score: 0.2976
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6317
# F1 Score: 0.2998
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6331
# F1 Score: 0.3007
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6346
# F1 Score: 0.2991
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6347
# F1 Score: 0.2996
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6323
# F1 Score: 0.2924
#
# Method: least_squares
# Average accuracy: 0.6333, Average F1-Score: 0.2983
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6309
# F1 Score: 0.3005
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6317
# F1 Score: 0.3008
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6336
# F1 Score: 0.2982
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6336
# F1 Score: 0.2995
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6305
# F1 Score: 0.2918
#
# Method: least_squares
# Average accuracy: 0.6320, Average F1-Score: 0.2981
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6284
# F1 Score: 0.2993
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6292
# F1 Score: 0.3003
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6291
# F1 Score: 0.2964
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6306
# F1 Score: 0.2986
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6282
# F1 Score: 0.2915
#
# Method: least_squares
# Average accuracy: 0.6291, Average F1-Score: 0.2972
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6285
# F1 Score: 0.2994
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6298
# F1 Score: 0.3005
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6289
# F1 Score: 0.2965
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6310
# F1 Score: 0.2988
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6280
# F1 Score: 0.2920
#
# Method: least_squares
# Average accuracy: 0.6292, Average F1-Score: 0.2974
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6009
# F1 Score: 0.2823
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6017
# F1 Score: 0.2816
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.5988
# F1 Score: 0.2765
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6009
# F1 Score: 0.2788
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6029
# F1 Score: 0.2742
#
# Method: least_squares
# Average accuracy: 0.6011, Average F1-Score: 0.2787
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6155
# F1 Score: 0.2953
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6165
# F1 Score: 0.2954
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6155
# F1 Score: 0.2917
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6167
# F1 Score: 0.2934
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6173
# F1 Score: 0.2873
#
# Method: least_squares
# Average accuracy: 0.6163, Average F1-Score: 0.2926
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6297
# F1 Score: 0.2994
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6311
# F1 Score: 0.2999
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6321
# F1 Score: 0.2979
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6318
# F1 Score: 0.2982
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6312
# F1 Score: 0.2924
#
# Method: least_squares
# Average accuracy: 0.6312, Average F1-Score: 0.2976
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6317
# F1 Score: 0.2998
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6331
# F1 Score: 0.3007
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6346
# F1 Score: 0.2991
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6347
# F1 Score: 0.2996
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6323
# F1 Score: 0.2924
#
# Method: least_squares
# Average accuracy: 0.6333, Average F1-Score: 0.2983
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6309
# F1 Score: 0.3005
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6317
# F1 Score: 0.3008
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6336
# F1 Score: 0.2982
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6336
# F1 Score: 0.2995
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6305
# F1 Score: 0.2918
#
# Method: least_squares
# Average accuracy: 0.6320, Average F1-Score: 0.2981
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6284
# F1 Score: 0.2993
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6292
# F1 Score: 0.3003
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6291
# F1 Score: 0.2964
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6306
# F1 Score: 0.2986
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6282
# F1 Score: 0.2915
#
# Method: least_squares
# Average accuracy: 0.6291, Average F1-Score: 0.2972
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6285
# F1 Score: 0.2994
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6298
# F1 Score: 0.3005
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6289
# F1 Score: 0.2965
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6310
# F1 Score: 0.2988
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6280
# F1 Score: 0.2920
#
# Method: least_squares
# Average accuracy: 0.6292, Average F1-Score: 0.2974
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6140
# F1 Score: 0.2872
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6135
# F1 Score: 0.2862
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6128
# F1 Score: 0.2816
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6135
# F1 Score: 0.2840
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6144
# F1 Score: 0.2792
#
# Method: least_squares
# Average accuracy: 0.6137, Average F1-Score: 0.2836
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6344
# F1 Score: 0.3029
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6340
# F1 Score: 0.3023
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6365
# F1 Score: 0.3005
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6349
# F1 Score: 0.3005
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6344
# F1 Score: 0.2943
#
# Method: least_squares
# Average accuracy: 0.6348, Average F1-Score: 0.3001
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6433
# F1 Score: 0.3058
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6437
# F1 Score: 0.3052
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6465
# F1 Score: 0.3037
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6454
# F1 Score: 0.3042
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6436
# F1 Score: 0.2978
#
# Method: least_squares
# Average accuracy: 0.6445, Average F1-Score: 0.3034
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6450
# F1 Score: 0.3059
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6455
# F1 Score: 0.3060
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6481
# F1 Score: 0.3048
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6476
# F1 Score: 0.3050
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6446
# F1 Score: 0.2980
#
# Method: least_squares
# Average accuracy: 0.6462, Average F1-Score: 0.3040
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6439
# F1 Score: 0.3061
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6451
# F1 Score: 0.3064
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6470
# F1 Score: 0.3042
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6462
# F1 Score: 0.3049
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6437
# F1 Score: 0.2982
#
# Method: least_squares
# Average accuracy: 0.6452, Average F1-Score: 0.3040
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6415
# F1 Score: 0.3059
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6427
# F1 Score: 0.3066
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6425
# F1 Score: 0.3021
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6435
# F1 Score: 0.3047
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6410
# F1 Score: 0.2977
#
# Method: least_squares
# Average accuracy: 0.6423, Average F1-Score: 0.3034
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6407
# F1 Score: 0.3053
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6417
# F1 Score: 0.3059
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6411
# F1 Score: 0.3018
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6439
# F1 Score: 0.3048
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6408
# F1 Score: 0.2978
#
# Method: least_squares
# Average accuracy: 0.6417, Average F1-Score: 0.3031
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6140
# F1 Score: 0.2872
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6135
# F1 Score: 0.2862
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6128
# F1 Score: 0.2816
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6135
# F1 Score: 0.2840
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6144
# F1 Score: 0.2792
#
# Method: least_squares
# Average accuracy: 0.6137, Average F1-Score: 0.2836
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6344
# F1 Score: 0.3029
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6340
# F1 Score: 0.3023
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6365
# F1 Score: 0.3005
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6349
# F1 Score: 0.3005
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6344
# F1 Score: 0.2943
#
# Method: least_squares
# Average accuracy: 0.6348, Average F1-Score: 0.3001
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6433
# F1 Score: 0.3058
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6437
# F1 Score: 0.3052
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6465
# F1 Score: 0.3037
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6454
# F1 Score: 0.3042
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6436
# F1 Score: 0.2978
#
# Method: least_squares
# Average accuracy: 0.6445, Average F1-Score: 0.3034
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6450
# F1 Score: 0.3059
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6455
# F1 Score: 0.3060
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6481
# F1 Score: 0.3048
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6476
# F1 Score: 0.3050
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6446
# F1 Score: 0.2980
#
# Method: least_squares
# Average accuracy: 0.6462, Average F1-Score: 0.3040
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6439
# F1 Score: 0.3061
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6451
# F1 Score: 0.3064
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6470
# F1 Score: 0.3042
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6462
# F1 Score: 0.3049
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6437
# F1 Score: 0.2982
#
# Method: least_squares
# Average accuracy: 0.6452, Average F1-Score: 0.3040
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6415
# F1 Score: 0.3059
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6427
# F1 Score: 0.3066
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6425
# F1 Score: 0.3021
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6435
# F1 Score: 0.3047
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6410
# F1 Score: 0.2977
#
# Method: least_squares
# Average accuracy: 0.6423, Average F1-Score: 0.3034
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6407
# F1 Score: 0.3053
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6417
# F1 Score: 0.3059
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6411
# F1 Score: 0.3018
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6439
# F1 Score: 0.3048
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6408
# F1 Score: 0.2978
#
# Method: least_squares
# Average accuracy: 0.6417, Average F1-Score: 0.3031
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6467
# F1 Score: 0.2992
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6476
# F1 Score: 0.2997
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6458
# F1 Score: 0.2930
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6508
# F1 Score: 0.2993
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6479
# F1 Score: 0.2924
#
# Method: least_squares
# Average accuracy: 0.6478, Average F1-Score: 0.2967
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6691
# F1 Score: 0.3173
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6722
# F1 Score: 0.3180
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6740
# F1 Score: 0.3169
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6725
# F1 Score: 0.3163
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6711
# F1 Score: 0.3095
#
# Method: least_squares
# Average accuracy: 0.6718, Average F1-Score: 0.3156
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6742
# F1 Score: 0.3197
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6777
# F1 Score: 0.3203
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6786
# F1 Score: 0.3191
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6789
# F1 Score: 0.3197
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6762
# F1 Score: 0.3123
#
# Method: least_squares
# Average accuracy: 0.6771, Average F1-Score: 0.3182
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6742
# F1 Score: 0.3192
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6771
# F1 Score: 0.3203
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6792
# F1 Score: 0.3189
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6797
# F1 Score: 0.3203
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6753
# F1 Score: 0.3121
#
# Method: least_squares
# Average accuracy: 0.6771, Average F1-Score: 0.3182
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6737
# F1 Score: 0.3189
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6757
# F1 Score: 0.3209
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6787
# F1 Score: 0.3190
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6782
# F1 Score: 0.3200
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6753
# F1 Score: 0.3124
#
# Method: least_squares
# Average accuracy: 0.6763, Average F1-Score: 0.3182
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6721
# F1 Score: 0.3201
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6727
# F1 Score: 0.3201
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6738
# F1 Score: 0.3174
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6748
# F1 Score: 0.3194
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6723
# F1 Score: 0.3116
#
# Method: least_squares
# Average accuracy: 0.6731, Average F1-Score: 0.3177
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6707
# F1 Score: 0.3197
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6720
# F1 Score: 0.3195
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6737
# F1 Score: 0.3168
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6745
# F1 Score: 0.3193
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6707
# F1 Score: 0.3115
#
# Method: least_squares
# Average accuracy: 0.6723, Average F1-Score: 0.3173
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6467
# F1 Score: 0.2992
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6476
# F1 Score: 0.2997
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6458
# F1 Score: 0.2930
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6508
# F1 Score: 0.2993
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6479
# F1 Score: 0.2924
#
# Method: least_squares
# Average accuracy: 0.6478, Average F1-Score: 0.2967
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6691
# F1 Score: 0.3173
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6722
# F1 Score: 0.3180
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6740
# F1 Score: 0.3169
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6725
# F1 Score: 0.3163
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6711
# F1 Score: 0.3095
#
# Method: least_squares
# Average accuracy: 0.6718, Average F1-Score: 0.3156
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6742
# F1 Score: 0.3197
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6777
# F1 Score: 0.3203
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6786
# F1 Score: 0.3191
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6789
# F1 Score: 0.3197
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6762
# F1 Score: 0.3123
#
# Method: least_squares
# Average accuracy: 0.6771, Average F1-Score: 0.3182
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6742
# F1 Score: 0.3192
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6771
# F1 Score: 0.3203
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6792
# F1 Score: 0.3189
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6797
# F1 Score: 0.3203
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6753
# F1 Score: 0.3121
#
# Method: least_squares
# Average accuracy: 0.6771, Average F1-Score: 0.3182
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6737
# F1 Score: 0.3189
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6757
# F1 Score: 0.3209
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6787
# F1 Score: 0.3190
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6782
# F1 Score: 0.3200
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6753
# F1 Score: 0.3124
#
# Method: least_squares
# Average accuracy: 0.6763, Average F1-Score: 0.3182
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6721
# F1 Score: 0.3201
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6727
# F1 Score: 0.3201
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6738
# F1 Score: 0.3174
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6748
# F1 Score: 0.3194
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6723
# F1 Score: 0.3116
#
# Method: least_squares
# Average accuracy: 0.6731, Average F1-Score: 0.3177
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6707
# F1 Score: 0.3197
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6720
# F1 Score: 0.3195
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.6737
# F1 Score: 0.3168
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6745
# F1 Score: 0.3193
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.6707
# F1 Score: 0.3115
#
# Method: least_squares
# Average accuracy: 0.6723, Average F1-Score: 0.3173
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6759
# F1 Score: 0.2156
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7735
# F1 Score: 0.2797
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.2716
# F1 Score: 0.1102
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.7003
# F1 Score: 0.2257
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.1920
# F1 Score: 0.1021
#
# Method: least_squares
# Average accuracy: 0.5227, Average F1-Score: 0.1867
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6880
# F1 Score: 0.2182
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7271
# F1 Score: 0.2407
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.2693
# F1 Score: 0.1094
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6942
# F1 Score: 0.2272
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.1930
# F1 Score: 0.1025
#
# Method: least_squares
# Average accuracy: 0.5143, Average F1-Score: 0.1796
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6835
# F1 Score: 0.2225
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6820
# F1 Score: 0.2465
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.3218
# F1 Score: 0.1039
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6157
# F1 Score: 0.2039
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.2095
# F1 Score: 0.0992
#
# Method: least_squares
# Average accuracy: 0.5025, Average F1-Score: 0.1752
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6691
# F1 Score: 0.2089
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6745
# F1 Score: 0.2372
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.3349
# F1 Score: 0.1074
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.5862
# F1 Score: 0.1864
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.2134
# F1 Score: 0.0995
#
# Method: least_squares
# Average accuracy: 0.4956, Average F1-Score: 0.1679
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.5048
# F1 Score: 0.1548
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6688
# F1 Score: 0.2165
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.3229
# F1 Score: 0.1077
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.4975
# F1 Score: 0.1517
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.2689
# F1 Score: 0.1056
#
# Method: least_squares
# Average accuracy: 0.4526, Average F1-Score: 0.1472
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.5105
# F1 Score: 0.1556
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7081
# F1 Score: 0.2367
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.3012
# F1 Score: 0.1062
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.4509
# F1 Score: 0.1365
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.2948
# F1 Score: 0.1094
#
# Method: least_squares
# Average accuracy: 0.4531, Average F1-Score: 0.1489
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.4822
# F1 Score: 0.1504
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6059
# F1 Score: 0.1882
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.3907
# F1 Score: 0.1174
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.4720
# F1 Score: 0.1391
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.3085
# F1 Score: 0.1109
#
# Method: least_squares
# Average accuracy: 0.4519, Average F1-Score: 0.1412
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6763
# F1 Score: 0.2160
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7738
# F1 Score: 0.2804
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.2719
# F1 Score: 0.1102
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.7004
# F1 Score: 0.2258
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.1921
# F1 Score: 0.1022
#
# Method: least_squares
# Average accuracy: 0.5229, Average F1-Score: 0.1869
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6882
# F1 Score: 0.2183
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7274
# F1 Score: 0.2407
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.2695
# F1 Score: 0.1094
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6943
# F1 Score: 0.2272
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.1930
# F1 Score: 0.1025
#
# Method: least_squares
# Average accuracy: 0.5144, Average F1-Score: 0.1796
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6835
# F1 Score: 0.2225
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6820
# F1 Score: 0.2465
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.3219
# F1 Score: 0.1041
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.6159
# F1 Score: 0.2041
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.2096
# F1 Score: 0.0992
#
# Method: least_squares
# Average accuracy: 0.5026, Average F1-Score: 0.1753
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6690
# F1 Score: 0.2089
#
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dg/jjw_9gyd1p38f4_jp_6s89r00000gn/T/ipykernel_95536/2327733267.py", line 52, in <module>
#     avg_accuracy, avg_f1 = cross_validate(
#                            ^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/Documents/EPFL/2024-25/MA1/CS-433 Machine learning/Project 1/utils.py", line 437, in cross_validate
#     preprocessed_x_train, preprocessed_x_test, preprocessed_y_train = preprocess(
#                                                                       ^^^^^^^^^^^
#   File "/Users/matthiaswyss/Documents/EPFL/2024-25/MA1/CS-433 Machine learning/Project 1/preprocess.py", line 53, in preprocess
#     x_train, x_test = remove_single_value_columns(x_train, x_test, verbose=verbose)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/Documents/EPFL/2024-25/MA1/CS-433 Machine learning/Project 1/preprocess.py", line 287, in remove_single_value_columns
#     single_value_columns = [
#                            ^
#   File "/Users/matthiaswyss/Documents/EPFL/2024-25/MA1/CS-433 Machine learning/Project 1/preprocess.py", line 290, in <listcomp>
#     if len(np.unique(x_train[:, col][~np.isnan(x_train[:, col])])) == 1
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<__array_function__ internals>", line 177, in unique
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "/Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
