# %%
from helpers import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from implementations import *
from utils import *
import utils
import preprocess
import importlib
importlib.reload(utils)
importlib.reload(preprocess)
# %load_ext autoreload
# %autoreload 2

# %%
x_train, x_test, y_train, train_ids, test_ids = load_csv_data("data/dataset")

# %%
avg_accuracy, avg_f1 = cross_validate(
    x_train,
    y_train,
    k=5,
    method='least_squares',
    replace_nan_by=-1,
    column_nan_threshold=0.01,
    row_nan_threshold=1,
    continuous_threshold=0,
    normalization_method='standardize',
    outliers=None,
    z_score_threshold=3,
    max_false_percentage=0.3,
    balance_method='random_upsampling',
    target_minority_ratio=0.2,
    noise_ratio=0.02,
    add_bias=False,
    pca_ratio=0.95,
    decision_threshold=0.2,
    lambda_=0.1,
    initial_w=None,
    max_iters=1000,
    gamma=0.0001,
    preprocess_verbose=True,
    cross_validation_verbose=True
)
# Out:
# Preprocessing for fold 1:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Original sizes:
#   - Majority class (0): 239373 (91.19%)
#   - Minority class (1): 23135 (8.81%)
# Minority class upsampled:
#   - Class (0): 239373 (80.00%)
#   - Class (1): 59843 (20.00%)
# PCA performed to reduce features from 315 to 299.
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.8723
# F1 Score: 0.4181
#
# Preprocessing for fold 2:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Original sizes:
#   - Majority class (0): 239386 (91.19%)
#   - Minority class (1): 23122 (8.81%)
# Minority class upsampled:
#   - Class (0): 239386 (80.00%)
#   - Class (1): 59846 (20.00%)
# PCA performed to reduce features from 315 to 299.
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.8717
# F1 Score: 0.4158
#
# Preprocessing for fold 3:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Original sizes:
#   - Majority class (0): 239289 (91.15%)
#   - Minority class (1): 23219 (8.85%)
# Minority class upsampled:
#   - Class (0): 239289 (80.00%)
#   - Class (1): 59822 (20.00%)
# PCA performed to reduce features from 315 to 299.
#
# Results for fold 3:
# Method: least_squares
# Accuracy: 0.8737
# F1 Score: 0.4230
#
# Preprocessing for fold 4:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Original sizes:
#   - Majority class (0): 239396 (91.20%)
#   - Minority class (1): 23112 (8.80%)
# Minority class upsampled:
#   - Class (0): 239396 (80.00%)
#   - Class (1): 59849 (20.00%)
# PCA performed to reduce features from 315 to 299.
#
# Results for fold 4:
# Method: least_squares
# Accuracy: 0.8703
# F1 Score: 0.4160
#
# Preprocessing for fold 5:
#
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Original sizes:
#   - Majority class (0): 239196 (91.12%)
#   - Minority class (1): 23312 (8.88%)
# Minority class upsampled:
#   - Class (0): 239196 (80.00%)
#   - Class (1): 59799 (20.00%)
# PCA performed to reduce features from 315 to 299.
#
# Results for fold 5:
# Method: least_squares
# Accuracy: 0.8715
# F1 Score: 0.4111
#
# Method: least_squares
# Average accuracy: 0.8719, Average F1-Score: 0.4168

# %%
predict_with_method(
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    test_ids=test_ids,
    method='least_squares',
    lambda_=0.1,
    initial_w=None,
    max_iters=1000,
    gamma=0.01,
    replace_nan_by=-1,
    column_nan_threshold=0.01,
    row_nan_threshold=1,
    continuous_threshold=0,
    normalization_method='standardize',
    outliers=None,
    z_score_threshold=3,
    max_false_percentage=0.3,
    balance_method='random_upsampling',
    target_minority_ratio=0.2,
    noise_ratio=0.02,
    add_bias=False,
    pca_ratio=0.95,
    decision_threshold=0.2,
    preprocess_verbose=True
)
# Out:
# Preprocessing data...
# Labels converted from -1 to 0.
# 6 features where all values are the same removed.
# Replaced all NaN values with -1.
# Data standardized using z-score scaling.
# Original sizes:
#   - Majority class (0): 299160 (91.17%)
#   - Minority class (1): 28975 (8.83%)
# Minority class upsampled:
#   - Class (0): 299160 (80.00%)
#   - Class (1): 74790 (20.00%)
# PCA performed to reduce features from 315 to 299.
# Number of predicted labels -1: 95028
# Number of predicted labels 1: 14351
# array([[328135,     -1],
#        [328136,     -1],
#        [328137,     -1],
#        ...,
#        [437511,     -1],
#        [437512,      1],
#        [437513,     -1]])

# %%
# Least squares hyperparameter tuning

best_avg_accuracy = 0
best_avg_f1 = 0

# Best parameters storage
best_params_accuracy = {
    'replace_nan_by': None,
    'column_nan_threshold': None,
    'row_nan_threshold': None,
    'continuous_threshold': None,
    'normalization_method': None,
    'outliers': None,
    'z_score_threshold': None,
    'max_false_percentage': None,
    'balance_method': None,
    'target_minority_ratio': None,
    'noise_ratio': None,
    'add_bias': None,
    'pca_ratio': None,
    'decision_threshold': None
}

best_params_f1 = {
    'replace_nan_by': None,
    'column_nan_threshold': None,
    'row_nan_threshold': None,
    'continuous_threshold': None,
    'normalization_method': None,
    'outliers': None,
    'z_score_threshold': None,
    'max_false_percentage': None,
    'balance_method': None,
    'target_minority_ratio': None,
    'noise_ratio': None,
    'add_bias': None,
    'pca_ratio': None,
    'decision_threshold': None
}

# Iterate through parameter combinations
for replace_nan_by in [-1]:
    for column_nan_threshold in [None]:
        for row_nan_threshold in [None]:
            for continuous_threshold in [None]:
                for normalization_method in ['standardize']:
                    for outliers in [None]:
                        for z_score_threshold in [None]:
                            for max_false_percentage in [None]:
                                for balance_method in ['random_upsampling']:
                                    for target_minority_ratio in [0.2, 0.4, 0.6, 0.8]:
                                        for noise_ratio in [None]:
                                            for add_bias in [False]:
                                                for pca_ratio in [0.95]:
                                                    for decision_threshold in np.arange(0, 0.31, 0.01):

                                                        # Call cross-validation
                                                        avg_accuracy, avg_f1 = cross_validate(
                                                            x_train,
                                                            y_train,
                                                            k=2,
                                                            method='least_squares',
                                                            decision_threshold=decision_threshold,
                                                            replace_nan_by=replace_nan_by,
                                                            column_nan_threshold=column_nan_threshold,
                                                            row_nan_threshold=row_nan_threshold,
                                                            continuous_threshold=continuous_threshold,
                                                            normalization_method=normalization_method,
                                                            outliers=outliers,
                                                            z_score_threshold=z_score_threshold,
                                                            max_false_percentage=max_false_percentage,
                                                            balance_method=balance_method,
                                                            target_minority_ratio=target_minority_ratio,
                                                            noise_ratio=noise_ratio,
                                                            add_bias=add_bias,
                                                            pca_ratio=pca_ratio,
                                                            preprocess_verbose=False,
                                                            cross_validation_verbose=True
                                                        )

                                                        # Update best average accuracy
                                                        if avg_accuracy > best_avg_accuracy:
                                                            best_avg_accuracy = avg_accuracy
                                                            best_params_accuracy.update({
                                                                'replace_nan_by': replace_nan_by,
                                                                'column_nan_threshold': column_nan_threshold,
                                                                'row_nan_threshold': row_nan_threshold,
                                                                'continuous_threshold': continuous_threshold,
                                                                'normalization_method': normalization_method,
                                                                'outliers': outliers,
                                                                'z_score_threshold': z_score_threshold,
                                                                'max_false_percentage': max_false_percentage,
                                                                'balance_method': balance_method,
                                                                'target_minority_ratio': target_minority_ratio,
                                                                'noise_ratio': noise_ratio,
                                                                'add_bias': add_bias,
                                                                'pca_ratio': pca_ratio,
                                                                'decision_threshold': decision_threshold
                                                            })

                                                        # Update best average F1 score
                                                        if avg_f1 > best_avg_f1:
                                                            best_avg_f1 = avg_f1
                                                            best_params_f1.update({
                                                                'replace_nan_by': replace_nan_by,
                                                                'column_nan_threshold': column_nan_threshold,
                                                                'row_nan_threshold': row_nan_threshold,
                                                                'continuous_threshold': continuous_threshold,
                                                                'normalization_method': normalization_method,
                                                                'outliers': outliers,
                                                                'z_score_threshold': z_score_threshold,
                                                                'max_false_percentage': max_false_percentage,
                                                                'balance_method': balance_method,
                                                                'target_minority_ratio': target_minority_ratio,
                                                                'noise_ratio': noise_ratio,
                                                                'add_bias': add_bias,
                                                                'pca_ratio': pca_ratio,
                                                                'decision_threshold': decision_threshold
                                                            })

# Print results
print("Best Average Accuracy:", best_avg_accuracy)
print("Best Parameters for Accuracy:", best_params_accuracy)
print("Best Average F1 Score:", best_avg_f1)
print("Best Parameters for F1 Score:", best_params_f1)
# Out:
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6723
# F1 Score: 0.3232
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6738
# F1 Score: 0.3202
#
# Method: least_squares
# Average accuracy: 0.6730, Average F1-Score: 0.3217
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.6864
# F1 Score: 0.3303
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.6880
# F1 Score: 0.3270
#
# Method: least_squares
# Average accuracy: 0.6872, Average F1-Score: 0.3286
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.7005
# F1 Score: 0.3374
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7016
# F1 Score: 0.3341
#
# Method: least_squares
# Average accuracy: 0.7011, Average F1-Score: 0.3357
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.7146
# F1 Score: 0.3448
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7153
# F1 Score: 0.3412
#
# Method: least_squares
# Average accuracy: 0.7150, Average F1-Score: 0.3430
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.7277
# F1 Score: 0.3518
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7283
# F1 Score: 0.3480
#
# Method: least_squares
# Average accuracy: 0.7280, Average F1-Score: 0.3499
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.7402
# F1 Score: 0.3586
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.7409
# F1 Score: 0.3550
#
# Method: least_squares
# Average accuracy: 0.7406, Average F1-Score: 0.3568
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9055
# F1 Score: 0.3272
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9050
# F1 Score: 0.3271
#
# Method: least_squares
# Average accuracy: 0.9053, Average F1-Score: 0.3272
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9075
# F1 Score: 0.3128
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9072
# F1 Score: 0.3114
#
# Method: least_squares
# Average accuracy: 0.9073, Average F1-Score: 0.3121
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9090
# F1 Score: 0.2944
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9086
# F1 Score: 0.2946
#
# Method: least_squares
# Average accuracy: 0.9088, Average F1-Score: 0.2945
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9103
# F1 Score: 0.2733
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9098
# F1 Score: 0.2760
#
# Method: least_squares
# Average accuracy: 0.9100, Average F1-Score: 0.2746
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9109
# F1 Score: 0.2514
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9111
# F1 Score: 0.2587
#
# Method: least_squares
# Average accuracy: 0.9110, Average F1-Score: 0.2550
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9116
# F1 Score: 0.2309
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9120
# F1 Score: 0.2387
#
# Method: least_squares
# Average accuracy: 0.9118, Average F1-Score: 0.2348
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9122
# F1 Score: 0.2107
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9125
# F1 Score: 0.2178
#
# Method: least_squares
# Average accuracy: 0.9124, Average F1-Score: 0.2143
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9126
# F1 Score: 0.1909
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9129
# F1 Score: 0.1939
#
# Method: least_squares
# Average accuracy: 0.9127, Average F1-Score: 0.1924
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9126
# F1 Score: 0.1689
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9132
# F1 Score: 0.1732
#
# Method: least_squares
# Average accuracy: 0.9129, Average F1-Score: 0.1710
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9127
# F1 Score: 0.1488
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9133
# F1 Score: 0.1546
#
# Method: least_squares
# Average accuracy: 0.9130, Average F1-Score: 0.1517
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9127
# F1 Score: 0.1283
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9134
# F1 Score: 0.1353
#
# Method: least_squares
# Average accuracy: 0.9130, Average F1-Score: 0.1318
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9127
# F1 Score: 0.1128
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9134
# F1 Score: 0.1181
#
# Method: least_squares
# Average accuracy: 0.9131, Average F1-Score: 0.1154
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9126
# F1 Score: 0.0968
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9135
# F1 Score: 0.1024
#
# Method: least_squares
# Average accuracy: 0.9131, Average F1-Score: 0.0996
#
# Results for fold 1:
# Method: least_squares
# Accuracy: 0.9126
# F1 Score: 0.0825
#
# Results for fold 2:
# Method: least_squares
# Accuracy: 0.9134
# F1 Score: 0.0872
#
# Method: least_squares
# Average accuracy: 0.9130, Average F1-Score: 0.0849
#
# Best Average Accuracy: 0.9130754121394875
# Best Parameters for Accuracy: {'replace_nan_by': -1, 'column_nan_threshold': None, 'row_nan_threshold': None, 'continuous_threshold': None, 'normalization_method': 'standardize', 'outliers': None, 'z_score_threshold': None, 'max_false_percentage': None, 'balance_method': 'random_upsampling', 'target_minority_ratio': 0.8, 'noise_ratio': None, 'add_bias': False, 'pca_ratio': 0.95, 'decision_threshold': 0.28}
# Best Average F1 Score: 0.415498269008822
# Best Parameters for F1 Score: {'replace_nan_by': -1, 'column_nan_threshold': None, 'row_nan_threshold': None, 'continuous_threshold': None, 'normalization_method': 'standardize', 'outliers': None, 'z_score_threshold': None, 'max_false_percentage': None, 'balance_method': 'random_upsampling', 'target_minority_ratio': 0.2, 'noise_ratio': None, 'add_bias': False, 'pca_ratio': 0.95, 'decision_threshold': 0.2}
